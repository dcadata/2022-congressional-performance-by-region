# %% [markdown]
# # 2022 Congressional Differential Turnout/Abstention

# %% [markdown]
# (Excluding uncontested seats)
#
# Differential turnout favored Republicans. Congressional districts that voted more heavily for Trump in the 2020 presidential election experienced higher turnout in the 2022 midterms. This is in line with historical precedent in which the out-party outperforms in midterm elections.

# %%
import task

task.fit_model_for_turnout()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             turnoutRel   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     47.34
# Date:                Sun, 07 May 2023   Prob (F-statistic):           3.09e-19
# Time:                        15:20:34   Log-Likelihood:                 459.50
# No. Observations:                 416   AIC:                            -913.0
# Df Residuals:                     413   BIC:                            -900.9
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.7786      0.014     55.021      0.000       0.751       0.806
# isCompetitive[T.True]     0.0448      0.009      5.237      0.000       0.028       0.062
# votePctPres              -0.1937      0.025     -7.873      0.000      -0.242      -0.145
# ==============================================================================
# Omnibus:                        4.823   Durbin-Watson:                   0.866
# Prob(Omnibus):                  0.090   Jarque-Bera (JB):                4.619
# Skew:                          -0.212   Prob(JB):                       0.0993
# Kurtosis:                       2.706   Cond. No.                         8.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
