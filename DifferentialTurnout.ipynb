# %% [markdown]
# # 2022 Congressional Differential Turnout/Abstention

# %% [markdown]
# (Excluding uncontested seats)
#
# Differential turnout favored Republicans. Congressional districts that voted more heavily for Trump in the 2020 presidential election experienced higher turnout in the 2022 midterms. This is in line with historical precedent in which the out-party outperforms in midterm elections.

# %%
import task

task.fit_model_for_turnout(party='R')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             turnoutRel   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     30.76
# Date:                Sun, 07 May 2023   Prob (F-statistic):           3.53e-13
# Time:                        17:27:22   Log-Likelihood:                 465.62
# No. Observations:                 416   AIC:                            -925.2
# Df Residuals:                     413   BIC:                            -913.2
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.6081      0.013     47.242      0.000       0.583       0.633
# isCompetitive[T.True]     0.0429      0.008      5.102      0.000       0.026       0.059
# votePctPres               0.1491      0.025      5.974      0.000       0.100       0.198
# ==============================================================================
# Omnibus:                        6.498   Durbin-Watson:                   0.891
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                6.599
# Skew:                          -0.289   Prob(JB):                       0.0369
# Kurtosis:                       2.784   Cond. No.                         8.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
