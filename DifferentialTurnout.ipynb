# %% [markdown]
# # 2022 Congressional Differential Turnout/Abstention

# %% [markdown]
# Excluding uncontested seats
#
# Differential turnout favored Republicans. Congressional districts that voted more heavily for Trump in the 2020 presidential election experienced higher turnout in the 2022 midterms. This is in line with historical precedent in which the out-party outperforms in midterm elections.

# %%
import diff_turnout as dt

# %%
dt.view_differential_turnout_summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             turnoutRel   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     25.37
# Date:                Sat, 13 May 2023   Prob (F-statistic):           4.14e-11
# Time:                        11:29:05   Log-Likelihood:                 460.53
# No. Observations:                 409   AIC:                            -915.1
# Df Residuals:                     406   BIC:                            -903.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.6166      0.013     46.393      0.000       0.590       0.643
# ...

# %%
dt.view_differential_turnout_summary_by_location(['FL', 'NY', 'CA'])
